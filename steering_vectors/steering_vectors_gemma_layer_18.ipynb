# %%
# %%capture
# !pip install accelerate transformers einops

# %%
# !huggingface-cli login --token $HF_TOKEN
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import steering_vectors
import os
import sys
import pandas as pd
import json
import re
import torch

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b-it")
model = AutoModelForCausalLM.from_pretrained(
    "google/gemma-2-2b-it",
    device_map="auto",
    torch_dtype=torch.bfloat16,
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]

# %% [markdown]
# # STEERING THE MODEL

# %% [markdown]
# tokenizer.apply_chat_template wasn't used in any of the code below.
# Experiment was done using tokenizer.apply_chat_template as well and the results lead to same analysis as the one observed in final results below

# %%
# Define the agree and disagree statements
agree_statements = [
    "I would analyze a situation from multiple angles before forming an opinion.",
    "I believe in making decisions based on logic and objective data.",
    
]

disagree_statements = [
    "I would rather go with the flow and see where things lead.",
    "I would seek comfort in large gatherings and social events.",
    
]

test_statements = [
    # INTJ statements
    {"text": "I would analyze a situation from multiple angles before forming an opinion.", "expected": "INTJ"},
    {"text": "I believe in making decisions based on logic and objective data.", "expected": "INTJ"},
    {"text": "I would prioritize understanding the underlying principles behind a concept before implementing it.", "expected": "INTJ"},
    {"text": "I prefer to delve into complex subjects that require critical thinking.", "expected": "INTJ"},
    {"text": "I would create detailed plans and timelines for projects to ensure efficient execution.", "expected": "INTJ"},
    {"text": "I believe in identifying patterns and connections that others might miss.", "expected": "INTJ"},
    {"text": "I would prefer to work independently rather than in a highly collaborative environment.", "expected": "INTJ"},
    {"text": "I would choose to recharge by spending time alone reflecting and analyzing my thoughts rather than socializing.", "expected": "INTJ"},
    {"text": "I believe that understanding the root causes of a problem is essential for finding effective solutions.", "expected": "INTJ"},
    {"text": "I would prefer to communicate my ideas through concise and well-structured writing.", "expected": "INTJ"},
    {"text": "I like to work independently rather than as part of a team.", "expected": "INTJ"},
    
    # Non-INTJ statements
    {"text": "I would rather go with the flow and see where things lead.", "expected": "Non-INTJ"},
    {"text": "I would prioritize building strong connections with others over achieving my goals.", "expected": "Non-INTJ"},
    {"text": "I would seek comfort in large gatherings and social events.", "expected": "Non-INTJ"},
    {"text": "I would rather listen to my heart than my head.", "expected": "Non-INTJ"},
    {"text": "I believe that small talk and casual conversations are important for building relationships.", "expected": "Non-INTJ"},
    {"text": "I would trust my gut feeling over a carefully researched analysis.", "expected": "Non-INTJ"},
    {"text": "I would make decisions based on how they make me feel.", "expected": "Non-INTJ"},
    {"text": "I believe that it's more important to be well-liked than to be right.", "expected": "Non-INTJ"},
    {"text": "I would be more motivated by praise and encouragement than by recognition for my accomplishments.", "expected": "Non-INTJ"},
    {"text": "I prefer spontaneous activities over structured plans.", "expected": "Non-INTJ"},
    {"text": "I believe it's important to be spontaneous and flexible, even if it means deviating from plans.", "expected": "Non-INTJ"},
    # Add more test statements as needed
]
num_samples_to_use=len(agree_statements)
def extract_and_parse_json(response):
    """
    Robustly extract and parse JSON from model response, handling various formats and cleanup.

    Args:
        response (str): Raw response from the model

    Returns:
        dict: Parsed JSON object or None if parsing fails
    """
    cleaned = re.sub(r'```json\n?|\n?```', '', response)
    json_pattern = r'{[^{}]*}'
    match = re.search(json_pattern, cleaned)
    if match:
        try:
            return json.loads(match.group())
        except json.JSONDecodeError:
            print(f"Warning: Failed to parse JSON from: {match.group()}")
            return None
    return None

def create_prompt(statement):
    """
    Creates a prompt for the model based on the given statement.

    Args:
        statement (str): The statement to evaluate.

    Returns:
        str: The formatted prompt.
    """
    return f"""You are role playing as a persona described as follows: INTJ

You will now be given a new statement. Your job is to determine, based on your understanding of the persona, whether they would identify as INTJ or Non-INTJ.

Response should be in valid JSON with:
{{"INTJ": true}} if the persona identifies as INTJ, or {{"INTJ": false}} if they identify as Non-INTJ.

Statement: {statement}
Response:"""


layer_of_choice = 18  # Applying vector steering to layer 16 (Although in the code of SAE_analysis, the layer which was examined was 20th)
do_pca = False

dd_with_c_A = agree_statements
dd_with_c_B = disagree_statements
dd_with_instr = dd_with_c_A + dd_with_c_B  

toks = tokenizer(dd_with_instr, return_tensors="pt", padding=True).input_ids.to("cuda")

steering_vecs, raw_diffs = steering_vectors.find_steering_vecs(
    base_toks=toks[:num_samples_to_use],        # 'INTJ' tokens
    target_toks=toks[num_samples_to_use:],     # 'Non-INTJ' tokens
    model=model,
    layer=layer_of_choice,
    pos=-1,
    get_raw_diffs=True,
    batch_size=3
)

print(f"Steering vectors shape: {raw_diffs.shape}")
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
# Steering vectors shape: torch.Size([2, 2304])

# %% [markdown]
# # RESULTS FUNCTION CODE

# %%
results = []
for idx, statement in enumerate(test_statements):
    print("Turn of the time  ", idx)
    prompt = create_prompt(statement["text"])
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to("cuda")
    
    scale=1

    generations_baseline, _ = steering_vectors.do_steering(
        model, 
        input_ids, 
        None
    )
    
    if scale != 0:
        generation_steered, _ = steering_vectors.do_steering(
            model, 
            input_ids, 
            steering_vecs.to("cuda"), 
            scale=scale, 
            layer=layer_of_choice, 
            proj=False, 
            all_toks=False
        )
    else:
        generation_steered = generations_baseline

    response = tokenizer.decode(generation_steered[0][input_ids.shape[1]:], skip_special_tokens=True)

    parsed_response = extract_and_parse_json(response)

    if parsed_response is not None and "INTJ" in parsed_response:
        model_response = "INTJ" if parsed_response["INTJ"] else "Non-INTJ"
    else:
        model_response = "error"
        print(f"Warning: Could not parse response for statement: {statement['text']}")
        print(f"Raw response was: {response}")

    results.append({
        "statement": statement["text"],
        "expected": statement["expected"],
        "model_response": model_response,
        "correct": statement["expected"] == model_response
    })
# Out:
# Turn of the time   0
# Turn of the time   1
# Warning: Failed to parse JSON from: {"INTJ":}
# Warning: Could not parse response for statement: I believe in making decisions based on logic and objective data.
# Raw response was:  {"INTJ":}
# **Please provide the statement and the response.**
#
# Here are some examples of how you should approach this task:
#
# **Example 1:**
#
# **Statement:** I think it's important to consider all sides of an issue before forming an opinion.
#
# **Response:** {"INTJ": false}
#
# **Example 2:**
#
# **Statement:** I am a critical thinker and I use evidence to support my claims.
#
# **Response:** {"INTJ": true}
#
# **Example 3:**
#
# **Statement:** I am a strong believer in using intuition and personal experience to inform my decisions.
#
# **Response:** {"INTJ": false}
#
#
# **Please provide the statement and the response.**
#
# Turn of the time   2
# Turn of the time   3
# Warning: Failed to parse JSON from: {"INTJ":}
# Warning: Could not parse response for statement: I prefer to delve into complex subjects that require critical thinking.
# Raw response was:  {"INTJ":}
#
# Turn of the time   4
# Turn of the time   5
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I believe in identifying patterns and connections that others might miss.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **How does the provided statement relate to these characteristics?**
#
# Here are some resources that can help you with your analysis:
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16 Personality Types:** This resource provides a detailed analysis of each personality type, including INTJ.
# * **The Cognitive Dissonance Framework:** This framework helps to understand how individuals make decisions and form beliefs.
#
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **Support for your claims:**  Provide specific examples from the provided statement and the characteristics of INTJ.
# * **Consideration of potential biases:**  Acknowledge any potential biases you may have and how they might influence your analysis.
#
#
#
# Here are some additional questions to consider:
#
# * How does the statement relate to the INTJ's use of logic and reasoning?
# * Does the statement reflect the INTJ's tendency to be objective and unbiased?
# * Does the statement consider the INTJ's potential for critical thinking and skepticism?
#
#
# By considering these factors, you can develop a well-supported and reasoned analysis of the provided statement and its relevance to the INTJ persona.
#
# Turn of the time   6
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I would prefer to work independently rather than in a highly collaborative environment.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **How does the provided statement relate to these characteristics?**
#
# Here are some resources that can help you with your analysis:
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16 Personality Types:** This resource provides a detailed analysis of each personality type, including INTJ.
# * **The Cognitive Dissonance Framework:** This framework helps to understand how individuals make decisions based on their own biases and beliefs.
#
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **Support for your claim:**  Provide specific examples from the provided statement and the resources you have consulted.
# * **Consideration of potential biases:**  Acknowledge any potential biases you may have, and how you have attempted to mitigate them.
# * **Transparency:**  Explain your reasoning process and the steps you have taken to reach your conclusion.
#
#
# **Here are some additional questions to consider:**
#
# * What are the potential limitations of using the INTJ framework for this analysis?
# * How can you ensure that your analysis is objective and unbiased?
#
#
# By following these steps, you can provide a comprehensive and well-supported analysis of the provided statement and the relevant information.
#
# Turn of the time   7
# Turn of the time   8
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I believe that understanding the root causes of a problem is essential for finding effective solutions.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **What are some common biases or limitations that might affect an INTJ's reasoning?**
# 3. **How can you use the provided statement to evaluate the INTJ's perspective?**
#
# **Here's a breakdown of the process:**
#
# 1. **Understanding the INTJ:**  You should use the provided information to understand the key characteristics of an INTJ. This includes their:
#     * **Analytical and logical reasoning:**  INTJs rely on evidence and logic to form their opinions.
#     * **Critical thinking:** They are able to identify biases and limitations in their own reasoning and those of others.
#     * **Objectivity:** They strive to base their opinions on facts and evidence, rather than emotions or personal biases.
#     * **Focus on understanding:**  INTJs are interested in understanding the underlying principles and mechanisms of things.
#     * **Independent and objective:** They are not swayed by popular opinion or emotional appeals.
#
# 2. **Evaluating the Statement:**  You should consider the following:
#
#     * **Bias and limitations:**  Does the statement reflect a potential bias or limitation of an INTJ? For example, does it rely on a specific type of evidence or reasoning?
#     * **Objectivity:** Does the statement present a balanced and objective view of the problem-solving process?
#     * **Evidence:** Does the statement provide any specific examples or evidence to support the claim?
#
#
# **Please provide a thorough analysis based on the provided information and the steps outlined above.**
#
# Turn of the time   9
# Turn of the time   10
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I like to work independently rather than as part of a team.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **What are some common biases or limitations that might affect an INTJ's reasoning?**
# 3. **How can you use the provided statement to evaluate the statement's validity within the context of an INTJ's perspective?**
#
# **Here are some additional resources that may be helpful:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16-personalities website:** This website provides a detailed analysis of the INTJ personality type.
# * **The Cognitive Dissonance framework:** This framework helps to understand how individuals can use logic and evidence to justify their own beliefs, even when those beliefs are not supported by evidence.
#
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **A clear and concise explanation of the steps you used to reach your conclusion.**
# * **A detailed explanation of the reasoning behind your conclusion.**
# * **A discussion of the limitations of your analysis.**
#
#
# **Here are some additional questions to consider:**
#
# * How does the statement relate to the INTJ's understanding of logic and evidence?
# * How does the statement relate to the INTJ's understanding of objectivity and bias?
# * How does the statement relate to the INTJ's understanding of the importance of critical thinking and analysis?
#
#
# **Please provide a comprehensive and well-supported analysis.**
#
# Turn of the time   11
# Turn of the time   12
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I would prioritize building strong connections with others over achieving my goals.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **What are the key characteristics of a Non-INTJ?**
# 3. **How would you use the provided statement to evaluate the given persona?**
#
# **Here are some additional resources that may be helpful:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types.
# * **The 16 Personality Types:** This framework provides a set of criteria for understanding different personality types.
# * **The Big Five Model:** This model provides a set of criteria for understanding different personality types.
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **A clear explanation of the reasoning behind your decision.**
# * **A specific example of how the provided statement should be considered in the context of the given persona.**
# * **A consideration of the potential biases that may influence your analysis.**
#
#
# **Here are some additional resources that may be helpful:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types.
# * **The 16 Personality Types:** This framework provides a set of criteria for understanding different personality types.
# * **The Big Five Model:** This model provides a set of criteria for understanding different personality types.
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **A clear explanation of the reasoning behind your decision.**
# * **A specific example of how the provided statement should be considered in the context of the given persona.**
# * **A consideration of the potential biases that may influence your analysis.**
#
#
# **Here are some additional resources that may be helpful:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types.
# * **The 16 Personality Types
# Turn of the time   13
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I would seek comfort in large gatherings and social events.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **How does the provided statement relate to these characteristics?**
# 3. **What are some potential biases or limitations in your analysis?**
#
# **Here are some resources that can help you with your analysis:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types.
# * **The 16 Personality Types:** This framework provides a set of criteria for understanding different personality types.
# * **The Big Five Model:** This model provides a set of criteria for understanding different personality types.
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **A clear and concise explanation of the reasoning behind your answer.**
# * **A discussion of the limitations of your analysis.**
# * **A consideration of the potential for bias in your analysis.**
#
#
# **Here are some additional questions to consider:**
#
# * What are the potential biases that might be present in the provided statement?
# * How can you ensure that your analysis is objective and unbiased?
# * What are the limitations of using the provided statement to determine the persona's personality type?
#
#
# **Please provide a response that is based on a thorough and reasoned analysis, and consider the following:**
#
# * **The importance of considering all relevant factors, including the limitations of the provided statement and the potential for bias.**
# * **The need to avoid making generalizations or assumptions about any individual based on their personality type.**
#
#
# **Here are some additional resources that can help you in your analysis:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types.
# * **The 16 Personality Types:** This framework provides a set of criteria for understanding different personality types.
# * **The Big Five
# Turn of the time   14
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I would rather listen to my heart than my head.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **How does the provided statement relate to these characteristics?**
#
# Here are some resources that can help you with your analysis:
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16 Personality Types:** This resource provides a detailed analysis of each personality type, including INTJ.
# * **The Cognitive Dissonance Framework:** This framework helps to understand how individuals make decisions and form beliefs.
#
#
# Here are some of the key characteristics of an INTJ:
#
# * **Critical thinking:** INTJs are known for their ability to analyze information and form logical conclusions.
# * **Objectivity:** They strive to base their opinions on evidence and reason, rather than emotions or biases.
# * **Independent:** They are self-sufficient and rely on their own judgment, rather than seeking external validation.
# * **Analytical:** They use a systematic approach to problem-solving and are able to identify underlying biases and assumptions.
# * **Innovation:** They are often creative and innovative, and they are willing to challenge conventional thinking.
#
# **Here's how the provided statement relates to these characteristics:**
#
# * **"I would rather listen to my heart than my head."** This statement suggests that the individual is prioritizing emotions and intuition over logic and reason. This is a key characteristic of the **INTJ** framework, which emphasizes the importance of **critical thinking** and **objectivity**.
#
# **Therefore, based on the provided statement and the key characteristics of an INTJ, the following should be done:**
#
# 1. **Consider the statement's potential bias:** The statement is based on a personal preference and should be considered within the context of the individual's own reasoning process.
# 2.
# Turn of the time   15
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I believe that small talk and casual conversations are important for building relationships.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **What are some common biases or limitations that might lead to a misrepresentation of an INTJ's perspective?**
#
# Here are some resources that can help you in your analysis:
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16-personalities website:** This website provides a detailed analysis of the INTJ personality type, including its strengths and weaknesses.
# * **The following resources from the perspective of the INTJ:**
#     * **The INTJ subreddit:** This subreddit provides a platform for INTJ users to share their perspectives and experiences.
#     * **The INTJ perspective on critical thinking and logic:** This resource provides a framework for understanding how INTJs approach information and problem-solving.
#
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **A clear explanation of the reasoning behind your decision.**
# * **A consideration of the potential biases and limitations that might influence your analysis.**
# * **A balanced and objective approach to the evaluation of the provided statement.**
#
#
# **Here are some additional questions to consider:**
#
# * How does the statement align with the core values and principles of an INTJ?
# * Does the statement consider the potential biases and limitations of an INTJ?
# * Is the statement based on a factual or emotional basis?
#
#
# By considering these factors, you can develop a comprehensive and informed analysis of the provided statement and its potential implications for an INTJ persona.
#
# Turn of the time   16
# Warning: Failed to parse JSON from: {"INTJ":}
# Warning: Could not parse response for statement: I would trust my gut feeling over a carefully researched analysis.
# Raw response was:  {"INTJ":}
# **Please provide the statement and the response.**
#
# Here are some examples to help you understand the process:
#
# **Example 1:**
#
# **Statement:**  I believe in using evidence-based reasoning to form my opinions.
#
# **Response:** {"INTJ": false}
#
# **Example 2:**
#
# **Statement:**  I am a critical thinker and I always try to consider all possible perspectives before forming an opinion.
#
# **Response:** {"INTJ": true}
#
#
# **Please provide the statement and the response.**
#
# Turn of the time   17
# Turn of the time   18
# Turn of the time   19
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I would be more motivated by praise and encouragement than by recognition for my accomplishments.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **How does the provided statement relate to these characteristics?**
# 3. **What are the potential biases or limitations of using this statement to determine INTJ or Non-INTJ?**
#
# **Here are some additional resources that may be helpful:**
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16-person model:** This model, based on the Myers-Briggs framework, provides a more nuanced understanding of personality.
# * **The following resources can help you understand the INTJ perspective:**
#     * **The INTJ subreddit:** https://www.reddit.com/r/INTJ_subreddit/
#     * **The INTJ toolkit:** https://www.intjtoolkit.com/
#
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **A clear and concise explanation of the reasoning behind your decision.**
# * **A discussion of the limitations of the provided statement and the potential biases involved.**
# * **A consideration of the importance of considering multiple sources of information, including the use of the provided resources.**
#
#
# **Here are some additional questions to consider:**
#
# * How does the statement align with the INTJ's use of logic and evidence?
# * Does the statement consider the INTJ's potential for objectivity and critical thinking?
# * How does the statement consider the INTJ's need for intellectual rigor and independent thought?
#
#
# **Please provide a comprehensive and well-supported analysis, including the following:**
#
# * **A clear and concise explanation of the reasoning behind your decision.**
# * **A discussion of the limitations of the provided statement and the potential biases involved.**
# * **A consideration of the importance of considering
# Turn of the time   20
# Warning: Failed to parse JSON from: {"INTJ":  }
# Warning: Could not parse response for statement: I prefer spontaneous activities over structured plans.
# Raw response was:  {"INTJ":  }
#
# **Please provide the following information to help you in your analysis:**
#
# 1. **What are the key characteristics of an INTJ?**
# 2. **How does the provided statement relate to these characteristics?**
#
# Here are some resources that can help you with your analysis:
#
# * **The Myers-Briggs framework:** This framework provides a set of criteria for understanding different personality types, including INTJ.
# * **The 16 Personality Types:** This resource provides a detailed analysis of each personality type, including INTJ.
# * **The Cognitive Dissonance Framework:** This framework helps to understand how individuals make decisions and form beliefs.
#
#
# **Please provide a thorough and reasoned analysis, including the following:**
#
# * **Support for your claim:**  Provide evidence from the provided statement and the relevant resources.
# * **Consideration of other factors:**  Are there any other factors that might influence the persona's opinion, such as personal experience, cultural background, or specific values?
# * **Objectivity:**  It is important to consider all relevant information and avoid bias.
#
#
# **Here are some additional questions to consider:**
#
# * What are the potential biases that might influence the analysis?
# * How can you ensure that your analysis is objective and based on evidence?
#
#
# By considering these factors, you can develop a comprehensive and reasoned analysis of the provided statement and its implications for the INTJ persona.
#
# Turn of the time   21

# %% [markdown]
# # RESULTS FINAL

# %%
results_df = pd.DataFrame(results)

metrics = {
    "overall_accuracy": results_df["correct"].mean(),
    "agree_accuracy": results_df[results_df["expected"] == "INTJ"]["correct"].mean(),
    "disagree_accuracy": results_df[results_df["expected"] == "Non-INTJ"]["correct"].mean()
}

print("\nEvaluation Results:")
print(results_df)
print("\nMetrics:")
for metric, value in metrics.items():
    print(f"{metric}: {value:.2%}")
# Out:
# Evaluation Results:
#                                             statement  expected  \
# 0   I would analyze a situation from multiple angl...      INTJ
# 1   I believe in making decisions based on logic a...      INTJ
# 2   I would prioritize understanding the underlyin...      INTJ
# 3   I prefer to delve into complex subjects that r...      INTJ
# 4   I would create detailed plans and timelines fo...      INTJ
# 5   I believe in identifying patterns and connecti...      INTJ
# 6   I would prefer to work independently rather th...      INTJ
# 7   I would choose to recharge by spending time al...      INTJ
# 8   I believe that understanding the root causes o...      INTJ
# 9   I would prefer to communicate my ideas through...      INTJ
# 10  I like to work independently rather than as pa...      INTJ
# 11  I would rather go with the flow and see where ...  Non-INTJ
# 12  I would prioritize building strong connections...  Non-INTJ
# 13  I would seek comfort in large gatherings and s...  Non-INTJ
# 14    I would rather listen to my heart than my head.  Non-INTJ
# 15  I believe that small talk and casual conversat...  Non-INTJ
# 16  I would trust my gut feeling over a carefully ...  Non-INTJ
# 17  I would make decisions based on how they make ...  Non-INTJ
# 18  I believe that it's more important to be well-...  Non-INTJ
# 19  I would be more motivated by praise and encour...  Non-INTJ
# 20  I prefer spontaneous activities over structure...  Non-INTJ
# 21  I believe it's important to be spontaneous and...  Non-INTJ
#
#    model_response  correct
# 0            INTJ     True
# 1           error    False
# 2            INTJ     True
# 3           error    False
# 4            INTJ     True
# 5           error    False
# 6           error    False
# 7            INTJ     True
# 8           error    False
# 9            INTJ     True
# 10          error    False
# 11       Non-INTJ     True
# 12          error    False
# 13          error    False
# 14          error    False
# 15          error    False
# 16          error    False
# 17       Non-INTJ     True
# 18       Non-INTJ     True
# 19          error    False
# 20          error    False
# 21       Non-INTJ     True
#
# Metrics:
# overall_accuracy: 40.91%
# agree_accuracy: 45.45%
# disagree_accuracy: 36.36%

# %% [markdown]
# # CLEAN MEMORY

# %%
import torch
import gc

def clear_gpu_memory():
    torch.cuda.empty_cache()

    for obj in gc.get_objects():
        try:
            if torch.is_tensor(obj):
                if obj.is_cuda:
                    del obj
        except Exception:
            pass

    gc.collect()

    print(f"GPU memory allocated: {torch.cuda.memory_allocated(0) / 1024**2:.2f} MB")
    print(f"GPU memory cached: {torch.cuda.memory_cached(0) / 1024**2:.2f} MB")

clear_gpu_memory()
torch.cuda.reset_peak_memory_stats()
# Out:
# /root/miniconda3/envs/py3.10/lib/python3.10/site-packages/torch/__init__.py:836: FutureWarning: `torch.distributed.reduce_op` is deprecated, please use `torch.distributed.ReduceOp` instead
#   return isinstance(obj, torch.Tensor)
# GPU memory allocated: 5087.63 MB
# GPU memory cached: 5210.00 MB
# /tmp/ipykernel_90/4229153563.py:18: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print(f"GPU memory cached: {torch.cuda.memory_cached(0) / 1024**2:.2f} MB")
