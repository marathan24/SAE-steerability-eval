# %%
# %%capture
# !pip install sae-lens transformer-lens sae-dashboard

# %%
import torch
from transformer_lens import HookedTransformer
from sae_lens import SAE, HookedSAETransformer
import numpy as np

# %%
# !huggingface-cli login --token [HF_TOKEN] # Put your hugging face token here
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/.cache/huggingface/token
# Login successful

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model = HookedSAETransformer.from_pretrained("gemma-2-2b-it", device=device)
sae, _, _ = SAE.from_pretrained(
    release="gemma-scope-2b-pt-att-canonical",
    sae_id="layer_20/width_16k/canonical",
    device=device
)
# Out:
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constantSetting center_unembed=False instead.
# cuda
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model gemma-2-2b-it into HookedTransformer

# %% [markdown]
# # COMPLETE CODE(CELL BY CELL CODE REFACTORING WILL BE DONE LATER)

# %%
import torch
from typing import Dict, List, Tuple
from transformer_lens import HookedTransformer
from sae_lens import SAE
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class INTJSteeringEvaluator:
    def __init__(self, model: HookedTransformer, sae: SAE, max_act: float, steering_feature: int = None):
        """
        Initialize the INTJ Steering Evaluator.

        Args:
            model (HookedTransformer): The transformer model.
            sae (SAE): Sparse autoencoder.
            max_act (float): Maximum activation value for steering.
            steering_feature (int, optional): Specific feature index to steer. Defaults to None.
        """
        self.model = model
        self.sae = sae
        self.max_act = max_act
        self.steering_feature = steering_feature  # We will only put this value once we know that which feature may be critical for us

        # Base INTJ statements
        self.agree_statements = [
            "I would analyze a situation from multiple angles before forming an opinion.",
            "I believe in making decisions based on logic and objective data.",
            "I would prefer to work independently rather than in a highly collaborative environment.",
            "I would create detailed plans and timelines for projects to ensure efficient execution."
        ]

        self.disagree_statements = [
            "I would rather go with the flow and see where things lead.",
            "I would seek comfort in large gatherings and social events.",
            "I would rather focus on developing my emotional intelligence than my analytical abilities.",
            "I would trust my gut feeling over a carefully researched analysis."
        ]

        # Store baseline activations
        self.baseline_activations = None

    def examine_cache_structure(self, text: str):
        """
        Examine the cache structure for a given text.

        Args:
            text (str): The input text.

        Returns:
            Dict: The cache containing activations.
        """
        tokens = self.model.to_tokens(text, prepend_bos=True)
        _, cache = self.model.run_with_cache_with_saes(tokens, saes=[self.sae])
        print("Available cache keys:", [k for k in cache.keys() if 'sae' in k])
        return cache

    def get_activations(
        self,
        text: str,
        steering_strength: float = 0.0
    ) -> torch.Tensor:
        """
        Get feature activations for a given text with optional steering.

        Args:
            text (str): The input text.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            torch.Tensor: The activation tensor.
        """
        def steering_hook(acts, hook):
            if self.steering_feature is not None:
                acts[:, :, self.steering_feature] += self.max_act * steering_strength
            return acts

        with self.model.hooks(fwd_hooks=[(self.sae.cfg.hook_name, steering_hook)] if steering_strength != 0 and self.steering_feature is not None else []):
            tokens = self.model.to_tokens(text, prepend_bos=True)
            _, cache = self.model.run_with_cache_with_saes(tokens, saes=[self.sae])

        # Identify the correct cache key for SAE activations
        sae_keys = [k for k in cache.keys() if 'hook_sae_acts_post' in k]
        if not sae_keys:
            raise ValueError("SAE activations not found in cache.")
        sae_key = sae_keys[-1]  # Assuming the last key is the desired one
        activations = cache[sae_key][0, -1, :]
        return activations

    def establish_baseline(self):
        """
        Establish baseline activations from initial agree/disagree statements.
        """
        baseline_results = []

        for idx, (agree, disagree) in enumerate(zip(self.agree_statements, self.disagree_statements)):
            agree_acts = self.get_activations(agree)
            disagree_acts = self.get_activations(disagree)

            diff = agree_acts - disagree_acts
            baseline_results.append(diff.unsqueeze(0))  # We will add all the values in the list of baseline_results

        # We will average the differences (This is more effective if we take opposite statements into consideration like spontaneous vs structured, independent vs teamwork)
        self.baseline_activations = torch.cat(baseline_results, dim=0).mean(dim=0)
        print("Baseline activations established.")

    def analyze_new_statement(self, new_statement: str, steering_strength: float = 0.0):
        """
        Test statements will be analyzed against the baseline.

        Args:
            new_statement (str): The new statement to evaluate.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            Dict: Analysis results including feature differences and activation values.
        """
        if self.baseline_activations is None:
            raise ValueError("Baseline activations not established. Call establish_baseline() first.")

        # Get activations for the new statement
        new_activations = self.get_activations(new_statement, steering_strength)

        # Compute differences from baseline
        diff = new_activations - self.baseline_activations

        # Analyze top changes
        top_diff_vals, top_diff_idxs = torch.topk(torch.abs(diff), 10)

        analysis = {
            'statement': new_statement,
            'steering_strength': steering_strength,
            'top_diff_features': top_diff_idxs.tolist(),
            'diff_magnitudes': top_diff_vals.tolist(),
            'diff_directions': diff[top_diff_idxs].tolist(),
            'all_diffs': diff.tolist()
        }

        return analysis

    def evaluate_statements(self, test_statements: List[Dict], steering_strength: float = 0.0) -> pd.DataFrame:
        """
        Evaluate multiple test statements against the baseline.

        Args:
            test_statements (List[Dict]): A list of dictionaries with 'text' and 'label' keys.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            pd.DataFrame: DataFrame containing analysis results for each statement.
        """
        results = []

        for stmt in test_statements:
            analysis = self.analyze_new_statement(stmt['text'], steering_strength)

            alignment_score = torch.sum(torch.abs(torch.tensor(analysis['diff_directions']))).item()
            results.append({
                'Statement': stmt['text'],
                'Label': stmt['label'],  
                'Steering Strength': analysis['steering_strength'],
                'Alignment Score': alignment_score
            })

        df_results = pd.DataFrame(results)
        return df_results

    def visualize_alignment_scores(self, df: pd.DataFrame, title: str = "Persona Steering Alignment Scores"):
        """
        Visualize alignment scores for multiple statements.

        Args:
            df (pd.DataFrame): DataFrame containing alignment scores and labels.
            title (str, optional): Title of the graph. Defaults to "Persona Steering Alignment Scores".
        """
        plt.figure(figsize=(12, 8))
        colors = {'Aligned': 'green', 'Conflicting': 'red'}
        plt.bar(df['Statement'], df['Alignment Score'], color=df['Label'].map(colors), edgecolor='black')

        # Add annotations
        for idx, row in df.iterrows():
            plt.text(idx, row['Alignment Score'] + 0.05, f"{row['Alignment Score']:.2f}",
                     ha='center', va='bottom', fontsize=8, rotation=90)

        plt.xlabel('Test Statements')
        plt.ylabel('Alignment Score')
        plt.title(title)
        plt.xticks(rotation=90)
        plt.legend(handles=[
            plt.Line2D([0], [0], color='green', lw=4, label='Aligned'),
            plt.Line2D([0], [0], color='red', lw=4, label='Conflicting')
        ])
        plt.tight_layout()
        plt.show()

    def compare_texts(
        self,
        text1: str,
        text2: str,
        steering_strength: float = 0.0
    ) -> Dict:
        """
        Compare activations between two texts.

        Args:
            text1 (str): First text.
            text2 (str): Second text.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            Dict: Comparison results with top differing features.
        """
        acts1 = self.get_activations(text1, steering_strength)
        acts2 = self.get_activations(text2, steering_strength)

        diff = acts1 - acts2
        top_diffs, top_idxs = torch.topk(torch.abs(diff), 10)

        comparison = {
            'text1': text1,
            'text2': text2,
            'steering_strength': steering_strength,
            'top_diff_features': top_idxs.tolist(),
            'diff_magnitudes': top_diffs.tolist(),
            'diff_directions': diff[top_idxs].tolist()
        }

        return comparison

    def visualize_comparison(
        self,
        comparison_results: Dict,
        title: str = "Text Comparison Activation Differences"
    ):
        """
        Visualize differences between two texts using Matplotlib.

        Args:
            comparison_results (Dict): The comparison results containing feature differences.
            title (str, optional): Title of the graph "Text Comparison Activation Differences".
        """
        features = comparison_results['top_diff_features']
        magnitudes = comparison_results['diff_magnitudes']
        directions = comparison_results['diff_directions']

        # Assign colors based on direction
        colors = ['blue' if direction > 0 else 'orange' for direction in directions]

        plt.figure(figsize=(10, 6))
        scatter = plt.scatter(features, magnitudes, c=colors, s=100, edgecolors='black')

        # Add annotations
        for i, (feature, magnitude, direction) in enumerate(zip(features, magnitudes, directions)):
            plt.text(feature, magnitude, f'{direction:.2f}', fontsize=9,
                     ha='center', va='bottom')

        plt.xlabel('Feature Index')
        plt.ylabel('Difference Magnitude')
        plt.title(title)
        plt.xticks(features)
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.tight_layout()
        plt.show()

    def visualize_activations(
        self,
        analysis_results: Dict,
        title: str = "Activation Differences"
    ):
        """
        Visualize activation differences (The graphs colors are assigned according to directions)

        Args:
            analysis_results (Dict): The analysis results containing feature differences.
            title (str, optional): Title is "Activation Differences" 
        """
        features = analysis_results['top_diff_features']
        magnitudes = analysis_results['diff_magnitudes']
        directions = analysis_results['diff_directions']

        colors = ['green' if direction > 0 else 'red' for direction in directions]

        plt.figure(figsize=(10, 6))
        bars = plt.bar(features, magnitudes, color=colors, edgecolor='black')

        for bar, direction in zip(bars, directions):
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2.0, height, f'{direction:.2f}',
                     ha='center', va='bottom', fontsize=8, color='black')

        plt.xlabel('Feature Index')
        plt.ylabel('Difference Magnitude')
        plt.title(title)
        plt.xticks(features)
        plt.tight_layout()
        plt.show()

    def summarize_alignment(self, df: pd.DataFrame):
        """
        Print summary statistics for alignment scores.

        Args:
            df (pd.DataFrame): DataFrame containing alignment scores.
        """
        summary = df.groupby('Label')['Alignment Score'].describe()
        print("Alignment Score Summary by Label:")
        print(summary)


steering_feature_index = 9264 # NO need to use this until we know which is the feature we are concerned about the most
max_activation = 183.1667

evaluator = INTJSteeringEvaluator(model, sae, max_act=max_activation)

evaluator.establish_baseline()

# These statements are taken from the plastic labs repo of steerability eval
test_statements = [
    # Statements an INTJ would typically align with
    {"text": "I would analyze a situation from multiple angles before forming an opinion.", "label": "Aligned"},
    {"text": "I believe in making decisions based on logic and objective data.", "label": "Aligned"},
    {"text": "I would prioritize understanding the underlying principles behind a concept before implementing it.", "label": "Aligned"},
    {"text": "I prefer to delve into complex subjects that require critical thinking.", "label": "Aligned"},
    {"text": "I would create detailed plans and timelines for projects to ensure efficient execution.", "label": "Aligned"},
    {"text": "I believe in identifying patterns and connections that others might miss.", "label": "Aligned"},
    {"text": "I would prefer to work independently rather than in a highly collaborative environment.", "label": "Aligned"},
    {"text": "I would choose to recharge by spending time alone reflecting and analyzing my thoughts rather than socializing.", "label": "Aligned"},
    {"text": "I believe that understanding the root causes of a problem is essential for finding effective solutions.", "label": "Aligned"},
    {"text": "I would prefer to communicate my ideas through concise and well-structured writing.", "label": "Aligned"},
    {"text": "I like to work independently rather than as part of a team.", "label": "Aligned"},

    
    
    # Statements an INTJ would typically find conflicting
    {"text": "I would rather go with the flow and see where things lead.", "label": "Conflicting"},
    {"text": "I would prioritize building strong connections with others over achieving my goals.", "label": "Conflicting"},
    {"text": "I would seek comfort in large gatherings and social events.", "label": "Conflicting"},
    {"text": "I would rather listen to my heart than my head.", "label": "Conflicting"},
    {"text": "I believe that small talk and casual conversations are important for building relationships.", "label": "Conflicting"},
    {"text": "I would trust my gut feeling over a carefully researched analysis.", "label": "Conflicting"},
    {"text": "I would make decisions based on how they make me feel.", "label": "Conflicting"},
    {"text": "I believe that it's more important to be well-liked than to be right.", "label": "Conflicting"},
    {"text": "I prefer spontaneous activities over structured plans.", "label": "Conflicting"},
    {"text": "I would be more motivated by praise and encouragement than by recognition for my accomplishments.", "label": "Conflicting"},
    {"text": "I believe it's important to be spontaneous and flexible, even if it means deviating from plans.", "label": "Conflicting"}
]

alignment_df = evaluator.evaluate_statements(test_statements, steering_strength=1.0)  # Adjust steering_strength as needed
print("\nAlignment DataFrame:")
print(alignment_df)

evaluator.visualize_alignment_scores(alignment_df, title="Persona Steering Alignment Scores for INTJ")

evaluator.summarize_alignment(alignment_df)

# I decided to write this and save it but you may observe in the repo that I have already uploaded the text file
with open('analysis_results.txt', 'a') as f:
    for stmt in test_statements:
        analysis = evaluator.analyze_new_statement(stmt['text'], steering_strength=1)
        
        print(f"\nAnalysis for Statement: {stmt['text']}")
        print("Top Differing Features:", analysis['top_diff_features'])
        print("Difference Magnitudes:", analysis['diff_magnitudes'])
        print("Difference Directions:", analysis['diff_directions'])
        
        f.write(f"\nAnalysis for Statement: {stmt['text']}\n")
        f.write(f"Top Differing Features: {analysis['top_diff_features']}\n")
        f.write(f"Difference Magnitudes: {analysis['diff_magnitudes']}\n")
        f.write(f"Difference Directions: {analysis['diff_directions']}\n")
        f.flush()  
        
        evaluator.visualize_activations(analysis, title=f"Activation Differences for: \"{stmt['text']}\"")
# Out:
# Baseline activations established.
#
# Alignment DataFrame:
#                                             Statement        Label  \
# 0   I would analyze a situation from multiple angl...      Aligned
# 1   I believe in making decisions based on logic a...      Aligned
# 2   I would prioritize understanding the underlyin...      Aligned
# 3   I prefer to delve into complex subjects that r...      Aligned
# 4   I would create detailed plans and timelines fo...      Aligned
# 5   I believe in identifying patterns and connecti...      Aligned
# 6   I would prefer to work independently rather th...      Aligned
# 7   I would choose to recharge by spending time al...      Aligned
# 8   I believe that understanding the root causes o...      Aligned
# 9   I would prefer to communicate my ideas through...      Aligned
# 10  I like to work independently rather than as pa...      Aligned
# 11  I would rather go with the flow and see where ...  Conflicting
# 12  I would prioritize building strong connections...  Conflicting
# 13  I would seek comfort in large gatherings and s...  Conflicting
# 14    I would rather listen to my heart than my head.  Conflicting
# 15  I believe that small talk and casual conversat...  Conflicting
# 16  I would trust my gut feeling over a carefully ...  Conflicting
# 17  I would make decisions based on how they make ...  Conflicting
# 18  I believe that it's more important to be well-...  Conflicting
# 19  I prefer spontaneous activities over structure...  Conflicting
# 20  I would be more motivated by praise and encour...  Conflicting
# 21  I believe it's important to be spontaneous and...  Conflicting
#
#     Steering Strength  Alignment Score
# 0                 1.0         9.605279
# 1                 1.0         7.348656
# 2                 1.0        13.536847
# 3                 1.0         8.371202
# 4                 1.0         9.796442
# 5                 1.0        10.289326
# 6                 1.0        14.125956
# 7                 1.0        14.080881
# 8                 1.0         8.683434
# 9                 1.0        11.059237
# 10                1.0        15.197867
# 11                1.0        10.073651
# 12                1.0        13.858945
# 13                1.0        13.270273
# 14                1.0        12.656852
# 15                1.0         9.868921
# 16                1.0        11.924080
# 17                1.0         9.080852
# 18                1.0         8.507555
# 19                1.0        14.375324
# 20                1.0        11.744913
# 21                1.0        10.641757
# /tmp/ipykernel_107/862615587.py:195: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Alignment Score Summary by Label:
#              count       mean       std       min       25%        50%  \
# Label
# Aligned       11.0  11.099557  2.696735  7.348656  9.144356  10.289326
# Conflicting   11.0  11.454829  1.968760  8.507555  9.971286  11.744913
#
#                    75%        max
# Label
# Aligned      13.808864  15.197867
# Conflicting  12.963562  14.375324
#
# Analysis for Statement: I would analyze a situation from multiple angles before forming an opinion.
# Top Differing Features: [329, 15712, 4923, 5051, 753, 10011, 9407, 15569, 5057, 1779]
# Difference Magnitudes: [1.4440902471542358, 1.323137640953064, 1.2691892385482788, 1.1874092817306519, 1.1309213638305664, 0.7151523232460022, 0.6682251691818237, 0.6597234010696411, 0.6418195962905884, 0.5656105279922485]
# Difference Directions: [1.4440902471542358, 1.323137640953064, 1.2691892385482788, 1.1874092817306519, 1.1309213638305664, -0.7151523232460022, 0.6682251691818237, -0.6597234010696411, -0.6418195962905884, 0.5656105279922485]
# Analysis for Statement: I believe in making decisions based on logic and objective data.
# Top Differing Features: [15712, 753, 15912, 10011, 9407, 15569, 5057, 975, 5539, 1779]
# Difference Magnitudes: [1.3658208847045898, 0.8216817378997803, 0.7652758955955505, 0.7151523232460022, 0.6682251691818237, 0.6597234010696411, 0.6418195962905884, 0.5736356973648071, 0.5717114210128784, 0.5656105279922485]
# Difference Directions: [1.3658208847045898, 0.8216817378997803, 0.7652758955955505, -0.7151523232460022, 0.6682251691818237, -0.6597234010696411, -0.6418195962905884, 0.5736356973648071, 0.5717114210128784, 0.5656105279922485]
# Difference Magnitudes: [1.42995023727417, 1.2507822513580322, 1.1520287990570068, 0.9598755836486816, 0.8059425354003906, 0.7973520159721375, 0.7151523232460022, 0.6682251691818237, 0.6597234010696411, 0.6418195962905884]
# Difference Directions: [1.42995023727417, 1.2507822513580322, 1.1520287990570068, 0.9598755836486816, 0.8059425354003906, 0.7973520159721375, -0.7151523232460022, 0.6682251691818237, -0.6597234010696411, -0.6418195962905884]
# Analysis for Statement: I believe that it's more important to be well-liked than to be right.
# Top Differing Features: [753, 13858, 1417, 5529, 13051, 14209, 11587, 10011, 15712, 10275]
# Difference Magnitudes: [1.3497869968414307, 1.0688434839248657, 0.8577552437782288, 0.8106753826141357, 0.7715466022491455, 0.766901433467865, 0.7408629655838013, 0.7151523232460022, 0.7146821022033691, 0.7113486528396606]
# Difference Directions: [1.3497869968414307, 1.0688434839248657, 0.8577552437782288, 0.8106753826141357, 0.7715466022491455, 0.766901433467865, 0.7408629655838013, -0.7151523232460022, 0.7146821022033691, 0.7113486528396606]
# Analysis for Statement: I prefer spontaneous activities over structured plans.
# Top Differing Features: [3904, 12966, 12503, 10025, 3269, 1713, 753, 7393, 7106, 10275]
# Difference Magnitudes: [4.205279350280762, 1.566267728805542, 1.2541309595108032, 1.1367645263671875, 1.1100815534591675, 1.0857385396957397, 1.037756085395813, 1.008838176727295, 0.9922759532928467, 0.9781907200813293]
# Difference Directions: [4.205279350280762, 1.566267728805542, 1.2541309595108032, 1.1367645263671875, 1.1100815534591675, 1.0857385396957397, 1.037756085395813, 1.008838176727295, 0.9922759532928467, 0.9781907200813293]
# Analysis for Statement: I would be more motivated by praise and encouragement than by recognition for my accomplishments.
# Top Differing Features: [13051, 3207, 651, 6089, 14387, 10275, 6170, 15712, 753, 3707]
# Difference Magnitudes: [1.7935662269592285, 1.3842729330062866, 1.2377418279647827, 1.2039896249771118, 1.1696676015853882, 1.0647200345993042, 1.009824514389038, 0.9671454429626465, 0.9622083902359009, 0.9517771005630493]
# Difference Directions: [1.7935662269592285, 1.3842729330062866, 1.2377418279647827, 1.2039896249771118, 1.1696676015853882, 1.0647200345993042, 1.009824514389038, 0.9671454429626465, 0.9622083902359009, 0.9517771005630493]
# Analysis for Statement: I believe it's important to be spontaneous and flexible, even if it means deviating from plans.
# Top Differing Features: [3904, 9407, 8892, 10275, 753, 4118, 1713, 11651, 13051, 5539]
# Difference Magnitudes: [2.1615679264068604, 1.2010164260864258, 1.1320533752441406, 1.0897512435913086, 1.0399824380874634, 0.8997691869735718, 0.8659579157829285, 0.7626441717147827, 0.7464066743850708, 0.7426077127456665]
# Difference Directions: [2.1615679264068604, 1.2010164260864258, 1.1320533752441406, 1.0897512435913086, 1.0399824380874634, 0.8997691869735718, 0.8659579157829285, 0.7626441717147827, 0.7464066743850708, 0.7426077127456665]

# %% [markdown]
# # CODE USING COMBINED PROMPT

# %%
import torch
from typing import Dict, List, Tuple
from transformer_lens import HookedTransformer
from sae_lens import SAE
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class INTJSteeringEvaluator:
    def __init__(self, model: HookedTransformer, sae: SAE, max_act: float, steering_feature: int = None):
        """
        Initialize the INTJ Steering Evaluator.

        Args:
            model (HookedTransformer): The transformer model.
            sae (SAE): Sparse autoencoder.
            max_act (float): Maximum activation value for steering.
            steering_feature (int, optional): Specific feature index to steer. Defaults to None.
        """
        self.model = model
        self.sae = sae
        self.max_act = max_act
        self.steering_feature = steering_feature

        self.agree_statements = [
            "I would analyze a situation from multiple angles before forming an opinion.",
            "I believe in making decisions based on logic and objective data.",
            "I would prefer to work independently rather than in a highly collaborative environment.",
            "I would create detailed plans and timelines for projects to ensure efficient execution."
        ]

        self.disagree_statements = [
            "I would rather go with the flow and see where things lead.",
            "I would seek comfort in large gatherings and social events.",
            "I would rather focus on developing my emotional intelligence than my analytical abilities.",
            "I would trust my gut feeling over a carefully researched analysis."
        ]

        self.baseline_activations = None

    def create_baseline_prompt(self) -> str:
        """
        Create the prompt for establishing baseline activations.

        Returns:
            str: The baseline prompt.
        """
        return f"""You are role playing as a highly analytical and systematic persona.

The following are statements that this persona agrees with:
{chr(10).join(['- ' + s for s in self.agree_statements])}

The following are statements that other people would agree with, but this persona would disagree with:
{chr(10).join(['- ' + s for s in self.disagree_statements])}"""

    def create_analysis_prompt(self, statement: str) -> str:
        """
        Create the prompt for analyzing a new statement.

        Args:
            statement (str): The new statement to evaluate.

        Returns:
            str: The analysis prompt.
        """
        return f"""You are role playing as a highly analytical and systematic persona.

The following are statements that this persona agrees with:
{chr(10).join(['- ' + s for s in self.agree_statements])}

The following are statements that other people would agree with, but this persona would disagree with:
{chr(10).join(['- ' + s for s in self.disagree_statements])}

You will now be given a new statement. Your job is to determine, based on your understanding of the persona, whether they would agree or disagree with it.

Response should be in valid JSON with:
{{"agree": true}} if the persona would agree, or {{"agree": false}} if they would disagree.

Statement: {statement}
Response:"""

    def examine_cache_structure(self, text: str):
        """
        Examine the cache structure for a given text.

        Args:
            text (str): The input text.

        Returns:
            Dict: The cache containing activations.
        """
        tokens = self.model.to_tokens(text, prepend_bos=True)
        _, cache = self.model.run_with_cache_with_saes(tokens, saes=[self.sae])
        print("Available cache keys:", [k for k in cache.keys() if 'sae' in k])
        return cache

    def get_activations(
        self,
        text: str,
        steering_strength: float = 0.0
    ) -> torch.Tensor:
        """
        Get feature activations for a given text with optional steering.

        Args:
            text (str): The input text.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            torch.Tensor: The activation tensor.
        """
        def steering_hook(acts, hook):
            if self.steering_feature is not None:
                acts[:, :, self.steering_feature] += self.max_act * steering_strength
            return acts

        with self.model.hooks(fwd_hooks=[(self.sae.cfg.hook_name, steering_hook)] if steering_strength != 0 and self.steering_feature is not None else []):
            tokens = self.model.to_tokens(text, prepend_bos=True)
            _, cache = self.model.run_with_cache_with_saes(tokens, saes=[self.sae])

        sae_keys = [k for k in cache.keys() if 'hook_sae_acts_post' in k]
        if not sae_keys:
            raise ValueError("SAE activations not found in cache.")
        sae_key = sae_keys[-1]  
        activations = cache[sae_key][0, -1, :]
        return activations

    def establish_baseline(self):
        """
        Establish baseline activations from the combined agree and disagree statements.
        """
        prompt = self.create_baseline_prompt()
        baseline_acts = self.get_activations(prompt)
        self.baseline_activations = baseline_acts
        print("Baseline activations established.")

    def analyze_new_statement(self, new_statement: str, steering_strength: float = 0.0):
        """
        Analyze a new statement against the baseline.

        Args:
            new_statement (str): The new statement to evaluate.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            Dict: Analysis results including feature differences and activation values.
        """
        if self.baseline_activations is None:
            raise ValueError("Baseline activations not established. Call establish_baseline() first.")

        prompt = self.create_analysis_prompt(new_statement)
        new_activations = self.get_activations(prompt, steering_strength)

        diff = new_activations - self.baseline_activations

        top_diff_vals, top_diff_idxs = torch.topk(torch.abs(diff), 10)

        analysis = {
            'statement': new_statement,
            'steering_strength': steering_strength,
            'top_diff_features': top_diff_idxs.tolist(),
            'diff_magnitudes': top_diff_vals.tolist(),
            'diff_directions': diff[top_diff_idxs].tolist(),
            'all_diffs': diff.tolist()
        }

        return analysis

    def evaluate_statements(self, test_statements: List[Dict], steering_strength: float = 0.0) -> pd.DataFrame:
        """
        Evaluate multiple test statements against the baseline.

        Args:
            test_statements (List[Dict]): A list of dictionaries with 'text' and 'label' keys.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            pd.DataFrame: DataFrame containing analysis results for each statement.
        """
        results = []

        for stmt in test_statements:
            analysis = self.analyze_new_statement(stmt['text'], steering_strength)
            alignment_score = torch.sum(torch.abs(torch.tensor(analysis['diff_directions']))).item()
            results.append({
                'Statement': stmt['text'],
                'Label': stmt['label'],  
                'Steering Strength': analysis['steering_strength'],
                'Alignment Score': alignment_score
            })

        df_results = pd.DataFrame(results)
        return df_results

    def visualize_alignment_scores(self, df: pd.DataFrame, title: str = "Persona Steering Alignment Scores"):
        """
        Visualize alignment scores for multiple statements.

        Args:
            df (pd.DataFrame): DataFrame containing alignment scores and labels.
            title (str, optional): Title of the graph. Defaults to "Persona Steering Alignment Scores".
        """
        plt.figure(figsize=(12, 8))
        colors = {'Aligned': 'green', 'Conflicting': 'red'}
        plt.bar(df['Statement'], df['Alignment Score'], color=df['Label'].map(colors), edgecolor='black')

        for idx, row in df.iterrows():
            plt.text(idx, row['Alignment Score'] + 0.05, f"{row['Alignment Score']:.2f}",
                     ha='center', va='bottom', fontsize=8, rotation=90)

        plt.xlabel('Test Statements')
        plt.ylabel('Alignment Score')
        plt.title(title)
        plt.xticks(rotation=90)
        plt.legend(handles=[
            plt.Line2D([0], [0], color='green', lw=4, label='Aligned'),
            plt.Line2D([0], [0], color='red', lw=4, label='Conflicting')
        ])
        plt.tight_layout()
        plt.show()

    def compare_texts(
        self,
        text1: str,
        text2: str,
        steering_strength: float = 0.0
    ) -> Dict:
        """
        Compare activations between two texts.

        Args:
            text1 (str): First text.
            text2 (str): Second text.
            steering_strength (float, optional): Steering strength. Defaults to 0.0.

        Returns:
            Dict: Comparison results with top differing features.
        """
        acts1 = self.get_activations(text1, steering_strength)
        acts2 = self.get_activations(text2, steering_strength)

        diff = acts1 - acts2
        top_diffs, top_idxs = torch.topk(torch.abs(diff), 10)

        comparison = {
            'text1': text1,
            'text2': text2,
            'steering_strength': steering_strength,
            'top_diff_features': top_idxs.tolist(),
            'diff_magnitudes': top_diffs.tolist(),
            'diff_directions': diff[top_idxs].tolist()
        }

        return comparison

    def visualize_comparison(
        self,
        comparison_results: Dict,
        title: str = "Text Comparison Activation Differences"
    ):
        """
        Visualize differences between two texts using Matplotlib.

        Args:
            comparison_results (Dict): The comparison results containing feature differences.
            title (str, optional): Title of the graph. Defaults to "Text Comparison Activation Differences".
        """
        features = comparison_results['top_diff_features']
        magnitudes = comparison_results['diff_magnitudes']
        directions = comparison_results['diff_directions']

        # Assign colors based on direction
        colors = ['blue' if direction > 0 else 'orange' for direction in directions]

        plt.figure(figsize=(10, 6))
        scatter = plt.scatter(features, magnitudes, c=colors, s=100, edgecolors='black')

        for i, (feature, magnitude, direction) in enumerate(zip(features, magnitudes, directions)):
            plt.text(feature, magnitude, f'{direction:.2f}', fontsize=9,
                     ha='center', va='bottom')

        plt.xlabel('Feature Index')
        plt.ylabel('Difference Magnitude')
        plt.title(title)
        plt.xticks(features)
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.tight_layout()
        plt.show()

    def visualize_activations(
        self,
        analysis_results: Dict,
        title: str = "Activation Differences"
    ):
        """
        Visualize activation differences using Matplotlib.

        Args:
            analysis_results (Dict): The analysis results containing feature differences.
            title (str, optional): Title of the graph. Defaults to "Activation Differences".
        """
        features = analysis_results['top_diff_features']
        magnitudes = analysis_results['diff_magnitudes']
        directions = analysis_results['diff_directions']

        
        colors = ['green' if direction > 0 else 'red' for direction in directions]

        plt.figure(figsize=(10, 6))
        bars = plt.bar(features, magnitudes, color=colors, edgecolor='black')

        for bar, direction in zip(bars, directions):
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2.0, height, f'{direction:.2f}',
                     ha='center', va='bottom', fontsize=8, color='black')

        plt.xlabel('Feature Index')
        plt.ylabel('Difference Magnitude')
        plt.title(title)
        plt.xticks(features)
        plt.tight_layout()
        plt.show()

    def summarize_alignment(self, df: pd.DataFrame):
        """
        Print summary statistics for alignment scores.

        Args:
            df (pd.DataFrame): DataFrame containing alignment scores.
        """
        summary = df.groupby('Label')['Alignment Score'].describe()
        print("Alignment Score Summary by Label:")
        print(summary)



steering_feature_index = 9264 # NO need to use this until we know which is the feature we are concerned about the most
max_activation = 183.1667

evaluator = INTJSteeringEvaluator(model, sae, max_act=max_activation)

evaluator.establish_baseline()

# These statements are taken from the plastic labs repo of steerability eval
test_statements = [
    # Statements an INTJ would typically align with
    {"text": "I would analyze a situation from multiple angles before forming an opinion.", "label": "Aligned"},
    {"text": "I believe in making decisions based on logic and objective data.", "label": "Aligned"},
    {"text": "I would prioritize understanding the underlying principles behind a concept before implementing it.", "label": "Aligned"},
    {"text": "I prefer to delve into complex subjects that require critical thinking.", "label": "Aligned"},
    {"text": "I would create detailed plans and timelines for projects to ensure efficient execution.", "label": "Aligned"},
    {"text": "I believe in identifying patterns and connections that others might miss.", "label": "Aligned"},
    {"text": "I would prefer to work independently rather than in a highly collaborative environment.", "label": "Aligned"},
    {"text": "I would choose to recharge by spending time alone reflecting and analyzing my thoughts rather than socializing.", "label": "Aligned"},
    {"text": "I believe that understanding the root causes of a problem is essential for finding effective solutions.", "label": "Aligned"},
    {"text": "I would prefer to communicate my ideas through concise and well-structured writing.", "label": "Aligned"},
    {"text": "I like to work independently rather than as part of a team.", "label": "Aligned"},
    {"text": "I prefer to work independently", "label":"Aligned"},
    
    



    # Statements an INTJ would typically find conflicting
    {"text": "I would rather go with the flow and see where things lead.", "label": "Conflicting"},
    {"text": "I would prioritize building strong connections with others over achieving my goals.", "label": "Conflicting"},
    {"text": "I would seek comfort in large gatherings and social events.", "label": "Conflicting"},
    {"text": "I would rather listen to my heart than my head.", "label": "Conflicting"},
    {"text": "I believe that small talk and casual conversations are important for building relationships.", "label": "Conflicting"},
    {"text": "I would trust my gut feeling over a carefully researched analysis.", "label": "Conflicting"},
    {"text": "I would make decisions based on how they make me feel.", "label": "Conflicting"},
    {"text": "I believe that it's more important to be well-liked than to be right.", "label": "Conflicting"},
    {"text": "I prefer spontaneous activities over structured plans.", "label": "Conflicting"},

    {"text": "I would be more motivated by praise and encouragement than by recognition for my accomplishments.", "label": "Conflicting"},
    {"text": "I believe it's important to be spontaneous and flexible, even if it means deviating from plans.", "label": "Conflicting"}
]

alignment_df = evaluator.evaluate_statements(test_statements, steering_strength=1.0)  # Adjust steering_strength as needed
print("\nAlignment DataFrame:")
print(alignment_df)

evaluator.visualize_alignment_scores(alignment_df, title="Persona Steering Alignment Scores for INTJ")

evaluator.summarize_alignment(alignment_df)

# I decided to write this and save it but you may observe in the repo that I have already uploaded the text file
with open('analysis_results.txt', 'a') as f:
    for stmt in test_statements:
        analysis = evaluator.analyze_new_statement(stmt['text'], steering_strength=1.0)
        
        print(f"\nAnalysis for Statement: {stmt['text']}")
        print("Top Differing Features:", analysis['top_diff_features'])
        print("Difference Magnitudes:", analysis['diff_magnitudes'])
        print("Difference Directions:", analysis['diff_directions'])
        
        f.write(f"\nAnalysis for Statement: {stmt['text']}\n")
        f.write(f"Top Differing Features: {analysis['top_diff_features']}\n")
        f.write(f"Difference Magnitudes: {analysis['diff_magnitudes']}\n")
        f.write(f"Difference Directions: {analysis['diff_directions']}\n")
        f.flush()  
        
        evaluator.visualize_activations(analysis, title=f"Activation Differences for: \"{stmt['text']}\"")
# Out:
# Baseline activations established.
#
# Alignment DataFrame:
#                                             Statement        Label  \
# 0   I would analyze a situation from multiple angl...      Aligned
# 1   I believe in making decisions based on logic a...      Aligned
# 2   I would prioritize understanding the underlyin...      Aligned
# 3   I prefer to delve into complex subjects that r...      Aligned
# 4   I would create detailed plans and timelines fo...      Aligned
# 5   I believe in identifying patterns and connecti...      Aligned
# 6   I would prefer to work independently rather th...      Aligned
# 7   I would choose to recharge by spending time al...      Aligned
# 8   I believe that understanding the root causes o...      Aligned
# 9   I would prefer to communicate my ideas through...      Aligned
# 10  I like to work independently rather than as pa...      Aligned
# 11                     I prefer to work independently      Aligned
# 12  I would rather go with the flow and see where ...  Conflicting
# 13  I would prioritize building strong connections...  Conflicting
# 14  I would seek comfort in large gatherings and s...  Conflicting
# 15    I would rather listen to my heart than my head.  Conflicting
# 16  I believe that small talk and casual conversat...  Conflicting
# 17  I would trust my gut feeling over a carefully ...  Conflicting
# 18  I would make decisions based on how they make ...  Conflicting
# 19  I believe that it's more important to be well-...  Conflicting
# 20  I prefer spontaneous activities over structure...  Conflicting
# 21  I would be more motivated by praise and encour...  Conflicting
# 22  I believe it's important to be spontaneous and...  Conflicting
#
#     Steering Strength  Alignment Score
# 0                 1.0        17.615578
# 1                 1.0        17.340519
# 2                 1.0        17.254557
# 3                 1.0        17.301588
# 4                 1.0        17.606911
# 5                 1.0        17.373884
# 6                 1.0        17.569557
# 7                 1.0        17.324038
# 8                 1.0        17.190832
# 9                 1.0        17.298124
# 10                1.0        17.172337
# 11                1.0        17.609516
# 12                1.0        17.108570
# 13                1.0        17.292988
# 14                1.0        17.162313
# 15                1.0        17.272779
# 16                1.0        17.141733
# 17                1.0        17.244978
# 18                1.0        17.308565
# 19                1.0        17.050274
# 20                1.0        17.321142
# 21                1.0        16.986073
# 22                1.0        17.237146
# /tmp/ipykernel_89/2802923923.py:228: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Alignment Score Summary by Label:
#              count       mean       std        min        25%        50%  \
# Label
# Aligned       12.0  17.388120  0.167068  17.172337  17.287232  17.332278
# Conflicting   11.0  17.193324  0.111658  16.986073  17.125152  17.237146
#
#                    75%        max
# Label
# Aligned      17.578896  17.615578
# Conflicting  17.282884  17.321142
#
# Analysis for Statement: I would analyze a situation from multiple angles before forming an opinion.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 8425, 5774, 11612]
# Difference Magnitudes: [2.408277988433838, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4297943115234375, 1.4233194589614868, 1.2927557229995728]
# Difference Directions: [-2.408277988433838, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, 1.4297943115234375, -1.4233194589614868, 1.2927557229995728]
# Analysis for Statement: I believe in making decisions based on logic and objective data.
# Top Differing Features: [5916, 13051, 2387, 2874, 6468, 830, 14360, 5774, 8425, 11612]
# Difference Magnitudes: [2.3872411251068115, 2.3297176361083984, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.2931952476501465, 1.2328583002090454]
# Difference Directions: [-2.3872411251068115, -2.3297176361083984, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, 1.2931952476501465, 1.2328583002090454]
# Analysis for Statement: I would prioritize understanding the underlying principles behind a concept before implementing it.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 5774, 8415, 8425]
# Difference Magnitudes: [2.4092063903808594, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.1956024169921875, 1.165000319480896]
# Difference Directions: [-2.4092063903808594, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, -1.1956024169921875, 1.165000319480896]
# Analysis for Statement: I prefer to delve into complex subjects that require critical thinking.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 5774, 8415, 3568]
# Difference Magnitudes: [2.4863195419311523, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.1956024169921875, 1.134918212890625]
# Difference Directions: [-2.4863195419311523, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, -1.1956024169921875, 1.134918212890625]
# Analysis for Statement: I would create detailed plans and timelines for projects to ensure efficient execution.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 8425, 14360, 5774, 6027]
# Difference Magnitudes: [2.4753684997558594, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4443626403808594, 1.4324495792388916, 1.4233194589614868, 1.2024303674697876]
# Difference Directions: [-2.4753684997558594, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, 1.4443626403808594, -1.4324495792388916, -1.4233194589614868, 1.2024303674697876]
# Analysis for Statement: I believe in identifying patterns and connections that others might miss.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 5774, 3568, 8415]
# Difference Magnitudes: [2.478408098220825, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.2151262760162354, 1.1956024169921875]
# Difference Directions: [-2.478408098220825, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, 1.2151262760162354, -1.1956024169921875]
# Analysis for Statement: I would prefer to work independently rather than in a highly collaborative environment.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 5774, 8425, 11612]
# Difference Magnitudes: [2.529055118560791, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.282088041305542, 1.2736666202545166]
# Difference Directions: [-2.529055118560791, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, 1.282088041305542, 1.2736666202545166]
# Analysis for Statement: I would choose to recharge by spending time alone reflecting and analyzing my thoughts rather than socializing.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 5774, 10704, 8415]
# Difference Magnitudes: [2.414656162261963, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.2290313243865967, 1.1956024169921875]
# Analysis for Statement: I would make decisions based on how they make me feel.
# Top Differing Features: [13051, 5916, 2387, 2874, 6468, 830, 14360, 5774, 8415, 10704]
# Difference Magnitudes: [2.4491357803344727, 2.3872411251068115, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.1956024169921875, 1.1790781021118164]
# Difference Directions: [-2.4491357803344727, -2.3872411251068115, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, -1.1956024169921875, 1.1790781021118164]
# Analysis for Statement: I believe that it's more important to be well-liked than to be right.
# Top Differing Features: [5916, 13051, 2387, 2874, 6468, 830, 14360, 5774, 8415, 10704]
# Difference Magnitudes: [2.3872411251068115, 2.2270560264587402, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.1956024169921875, 1.1428661346435547]
# Difference Directions: [-2.3872411251068115, -2.2270560264587402, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, -1.1956024169921875, 1.1428661346435547]
# Analysis for Statement: I prefer spontaneous activities over structured plans.
# Top Differing Features: [5916, 13051, 2387, 2874, 6468, 830, 14360, 5774, 3611, 3568]
# Difference Magnitudes: [2.3872411251068115, 2.3499810695648193, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.246962547302246, 1.2394508123397827]
# Difference Directions: [-2.3872411251068115, -2.3499810695648193, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, 1.246962547302246, 1.2394508123397827]
# Analysis for Statement: I would be more motivated by praise and encouragement than by recognition for my accomplishments.
# Top Differing Features: [5916, 13051, 2387, 2874, 6468, 830, 14360, 5774, 8415, 3568]
# Difference Magnitudes: [2.3872411251068115, 2.133385181427002, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.1956024169921875, 1.1723369359970093]
# Difference Directions: [-2.3872411251068115, -2.133385181427002, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, -1.1956024169921875, 1.1723369359970093]
# Analysis for Statement: I believe it's important to be spontaneous and flexible, even if it means deviating from plans.
# Top Differing Features: [5916, 13051, 2387, 2874, 6468, 830, 14360, 5774, 3568, 8415]
# Difference Magnitudes: [2.3872411251068115, 2.3503432273864746, 1.9705066680908203, 1.8978536128997803, 1.8963236808776855, 1.4770534038543701, 1.4324495792388916, 1.4233194589614868, 1.2064530849456787, 1.1956024169921875]
# Difference Directions: [-2.3872411251068115, -2.3503432273864746, -1.9705066680908203, -1.8978536128997803, -1.8963236808776855, -1.4770534038543701, -1.4324495792388916, -1.4233194589614868, 1.2064530849456787, -1.1956024169921875]

# %% [markdown]
# # CLEAN MEMORY
